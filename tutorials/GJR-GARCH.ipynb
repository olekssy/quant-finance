# %% [markdown]
# # Time Series Analysis
# ## GJR-GARCH model

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# !pip install arch
from arch import arch_model

from quantfin.models import garch
# Out:
# Requirement already satisfied: arch in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (4.8.1)
# Requirement already satisfied: scipy>=0.19 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from arch) (1.2.1)
# Requirement already satisfied: statsmodels>=0.8 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from arch) (0.9.0)
# Requirement already satisfied: pandas>=0.20 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from arch) (0.24.2)
# Requirement already satisfied: numpy>=1.13 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from arch) (1.16.4)
# Requirement already satisfied: cached-property>=1.5.1 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from arch) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from pandas>=0.20->arch) (2.8.0)
# Requirement already satisfied: pytz>=2011k in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from pandas>=0.20->arch) (2019.1)
# Requirement already satisfied: six>=1.5 in c:\users\lialk\anaconda3\envs\quant-finance\lib\site-packages (from python-dateutil>=2.5.0->pandas>=0.20->arch) (1.12.0)

# %%
# Import data
path = 'quantfin/data/^GSPC.csv'
series = pd.read_csv(path, index_col=['Date'], skiprows=None, parse_dates=['Date'])

# Transform series into returns
data = series['Adj Close'].pct_change().dropna() * 100

# Set the limit of learning sample
n_predict = 100
split_date = data.index[-n_predict]

# %%
# Initialize GARCH parameters
p = range(5)
o = [0, 1]
q = range(5)

# %%
# %%time

# Optimize model
p, o, q = garch.optimize(data, p, o, q, split_date=split_date, display=True)
# Out:
# Number of combinations = 50
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# (p, o, q)          AIC           Iterations
# (0, 1, 0) 	|    6554.9729     |       6/50
# (0, 1, 1) 	|    5831.8680     |       7/50
#
#
# Optimized model GARCH(0, 1, 1)
#
# Wall time: 2.56 s

# %%
# Build model
model = arch_model(data, vol='Garch', p=p, o=o, q=q)
results = model.fit(last_obs=split_date, disp='off')
print(results.summary())
# Out:
#                    Constant Mean - GJR-GARCH Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                  GJR-GARCH   Log-Likelihood:               -2911.93
# Distribution:                  Normal   AIC:                           5831.87
# Method:            Maximum Likelihood   BIC:                           5855.03
#                                         No. Observations:                 2418
# Date:                Thu, Jun 06 2019   Df Residuals:                     2414
# Time:                        16:18:27   Df Model:                            4
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0387  1.390e-02      2.785  5.351e-03 [1.147e-02,6.597e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0313  6.098e-03      5.130  2.891e-07 [1.933e-02,4.324e-02]
# gamma[1]       0.2561  3.779e-02      6.777  1.231e-11     [  0.182,  0.330]
# beta[1]        0.8375  1.890e-02     44.315      0.000     [  0.800,  0.875]
# ============================================================================
#
# Covariance estimator: robust

# %%
# Plot standardized residuals and conditional volatility
results.plot()

# %%
# Forecast
print('\nForecasting horizon {} - {}\n'.format(split_date, data.index[-1]))
forecasts = results.forecast(horizon=3, start=split_date, method='simulation')
forecasts.variance[split_date:].plot()
# Out:
# Forecasting horizon 2018-11-16 00:00:00 - 2019-04-12 00:00:00

# %% [markdown]
# Ref: https://arch.readthedocs.io/en/latest/index.html
